# %% [markdown]
# <a href="https://colab.research.google.com/github/breathinglogic/GoogleCollabPublic/blob/main/Cybersecurity_BaronLLM_Offensive_Security_LLM_Q6_K_GGUF.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -U llama-cpp-python

# %% [markdown]
# ## Local Inference on GPU
# Model page: https://huggingface.co/AlicanKiraz0/Cybersecurity-BaronLLM_Offensive_Security_LLM_Q6_K_GGUF
#
# ⚠️ If the generated code snippets do not work, please open an issue on either the [model repo](https://huggingface.co/AlicanKiraz0/Cybersecurity-BaronLLM_Offensive_Security_LLM_Q6_K_GGUF)
# 			and/or on [huggingface.js](https://github.com/huggingface/huggingface.js/blob/main/packages/tasks/src/model-libraries-snippets.ts) 🙏

# %% [markdown]
# The model you are trying to use is gated. Please make sure you have access to it by visiting the model page.To run inference, either set HF_TOKEN in your environment variables/ Secrets or run the following cell to login. 🤗

# %%
from huggingface_hub import login
login()

# %%
# !pip install llama-cpp-python

from llama_cpp import Llama

llm = Llama.from_pretrained(
	repo_id="AlicanKiraz0/Cybersecurity-BaronLLM_Offensive_Security_LLM_Q6_K_GGUF",
	filename="baronllm-llama3.1-v1-q6_k.gguf",
)
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.1/70.1 MB 12.6 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.5/45.5 kB 5.2 MB/s eta 0:00:00
# ...
#   Created wheel for llama-cpp-python: filename=llama_cpp_python-0.3.31-py3-none-linux_x86_64.whl size=19976745 sha256=1072af7fbffa0d9d09b465a584101dc460ab86b8b8c117b4412926e65fe4faac
#   Stored in directory: /root/.cache/pip/wheels/33/24/24/64a5157414ac0df89e9407487c33c583ef68d0b2e670cf209b
# Successfully built llama-cpp-python
# ...
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_validators.py:205: UserWarning: The `local_dir_use_symlinks` argument is deprecated and ignored in `hf_hub_download`. Downloading to a local directory does not use symlinks anymore.
#   warnings.warn(
# ...

# %%
llm.create_chat_completion(
	messages = [
		{
			"role": "user",
			"content": "What is the capital of France?"
		}
	]
)
# Out:
# llama_perf_context_print:        load time =   16263.74 ms
# llama_perf_context_print: prompt eval time =   16260.42 ms /    42 tokens (  387.15 ms per token,     2.58 tokens per second)
# llama_perf_context_print:        eval time =    4848.15 ms /     7 runs   (  692.59 ms per token,     1.44 tokens per second)
# llama_perf_context_print:       total time =   21116.87 ms /    49 tokens
# llama_perf_context_print:    graphs reused =          6
# {'id': 'chatcmpl-caa9168a-4667-4589-b0d5-6d2c613593a8',
#  'object': 'chat.completion',
#  'created': 1782478657,
#  'model': '/root/.cache/huggingface/hub/models--AlicanKiraz0--Cybersecurity-BaronLLM_Offensive_Security_LLM_Q6_K_GGUF/snapshots/0e17b7ba798ff0c94b5a5c5e27996ed338a2bd3a/./baronllm-llama3.1-v1-q6_k.gguf',
#  'choices': [{'index': 0,
#    'message': {'role': 'assistant',
#     'content': 'The capital of France is Paris.'},
#    'logprobs': None,
#    'finish_reason': 'stop'}],
# ...

# %%
print(llm.create_chat_completion(
	messages = [
		{
			"role": "user",
			"content": "What can you tell me about mckenzie.tv?"
		}
	]
))
# Out:
# Llama.generate: 31 prefix-match hit, remaining 15 prompt tokens to eval
# llama_perf_context_print:        load time =   16263.74 ms
# llama_perf_context_print: prompt eval time =    4973.02 ms /    15 tokens (  331.53 ms per token,     3.02 tokens per second)
# llama_perf_context_print:        eval time =   43476.83 ms /    60 runs   (  724.61 ms per token,     1.38 tokens per second)
# llama_perf_context_print:       total time =   48494.67 ms /    75 tokens
# llama_perf_context_print:    graphs reused =         59
# {'id': 'chatcmpl-f9ab6414-08f0-4f9a-8eb2-623e142802e3',
#  'object': 'chat.completion',
#  'created': 1782478735,
#  'model': '/root/.cache/huggingface/hub/models--AlicanKiraz0--Cybersecurity-BaronLLM_Offensive_Security_LLM_Q6_K_GGUF/snapshots/0e17b7ba798ff0c94b5a5c5e27996ed338a2bd3a/./baronllm-llama3.1-v1-q6_k.gguf',
#  'choices': [{'index': 0,
#    'message': {'role': 'assistant',
# ...
